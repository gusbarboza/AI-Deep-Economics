# %% [markdown]
# <a href="https://colab.research.google.com/github/gusbarboza/AI-Deep-Economics/blob/main/TESIS_SEBA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import all the libraries for handling data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prompt: conect my google drive account this the folder https://drive.google.com/drive/folders/1qXqlCfj7OreAbeDgzwmkUwGDG-Y0X8JT

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Get the folder ID from the URL
folder_id = '1qXqlCfj7OreAbeDgzwmkUwGDG-Y0X8JT'

# Change the current working directory to the mounted Google Drive folder
# %cd /content/drive/My\ Drive

# Create a symbolic link to the folder
# !ln -s /content/drive/My\ Drive/{$folder_id} folder_name

# Change the current working directory to the linked folder
# %cd folder_name
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# [Errno 2] No such file or directory: 'folder_name'
# /content/drive/My Drive

# %%
# prompt: show the data from this path /content/drive/Othercomputers/My Laptop/PhD/Tesis Seba Msc/datos tesis bien (3).xlsx

df = pd.read_excel('/content/drive/Othercomputers/My Laptop/PhD/Tesis Seba Msc/datos tesis bien (3).xlsx')
df.head()
# Out:
#     Año  Semana   Novillitos 201 a 240 kg  Novillos 241 a 300 kg  \
# 0  2018        1                     1.81                   1.68
# 1  2018        2                     1.81                   1.70
# 2  2018        3                     1.81                   1.73
# 3  2018        4                     1.79                   1.73
# 4  2018        5                     1.80                   1.71
#
#    Novillos 301 a 360 kg  Novillos HQB 481  Novillos más 360 kg  \
# 0                   1.58              1.75                 1.51
# 1                   1.59              1.78                 1.55
# 2                   1.62              1.76                 1.53
# 3                   1.63              1.76                 1.53
# 4                   1.63              1.77                 1.50
#
#    Piezas de Cría  Terneras 141 a 200 kg  Terneras hasta 140 kg  ...  \
# 0             321                   1.66                   1.83  ...
# ...

# %%
# Load the specified sheet
file_path = '/content/drive/Othercomputers/My Laptop/PhD/Tesis Seba Msc/datos tesis bien (3).xlsx'
data = pd.read_excel(file_path, sheet_name='Datos corregidos')

# %%
# Check for missing values in the data
missing_values_summary = data.isnull().sum()

# %%
# Display columns with missing values
missing_values_summary[missing_values_summary > 0]
# Out:
# Novillos HQB 481                                      11
# Terneros exportación                                   7
# Vaquillonas HQB 481                                   92
# Novillos gordos abasto buenos en pie                  75
# Novillos gordos abasto buenos a la carne               3
# Novillos gordos abasto especiales en pie               4
# Novillos gordos abasto especiales a la carne           3
# Novillos gordos exportacion buenos en pie              9
# Novillos gordos exportacion buenos a la carne          3
# Novillos gordos exportacion especiales en pie         77
# Novillos gordos exportacion especiales a la carne      3
# Novillos gordos exportacion generales en pie         314
# Novillos gordos exportacion generales a la carne       4
# Vacas industria manufactura alta en pie               46
# Vacas industria manufactura alta a la carne            3
# Vacas industria manufactura baja en pie               46
# ...

# %%
# Imputar valores faltantes usando interpolación lineal
data_imputed = data.interpolate(method='linear')

# %%
output_file_path = '/content/drive/Othercomputers/My Laptop/PhD/Tesis Seba Msc/datos tesis bien imputados.xlsx'
data_imputed.to_excel(output_file_path, sheet_name='Datos corregidos', index=False)
